# %%
# %run ./clustering.py
# Out:
# C:\Users\alaac\OneDrive\Bureau\EPFL\LS Hackathon\65roses\clustering.py:25: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = raw_data.applymap(stable_hash) #np.empty((len(raw_data), len(raw_data.columns)))
#       Chromosome  Position  Reference  Alternate    Source  Transcript  \
# 0       0.427456  0.649736   0.707853   0.968404  0.913134    0.869210
# 1       0.427456  0.572897   0.707853   0.968404  0.913134    0.869210
# 2       0.427456  0.316751   0.707853   0.968404  0.913134    0.869210
# 3       0.427456  0.607406   0.302525   0.108746  0.913134    0.869210
# 4       0.427456  0.478303   0.108746   0.968404  0.913134    0.869210
# ...          ...       ...        ...        ...       ...         ...
# 5878    0.427456  0.903273   0.108746   0.462838  0.795489    0.746619
# 5879    0.427456  0.743782   0.707853   0.968404  0.848573    0.746619
# 5880    0.427456  0.187410   0.108746   0.462838  0.848573    0.746619
# ...
