# %%
# %run ./clustering.py
# Out:
# C:\Users\alaac\OneDrive\Bureau\EPFL\LS Hackathon\65roses\clustering.py:29: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = raw_data.applymap(stable_hash) #np.empty((len(raw_data), len(raw_data.columns)))
# True
# 0       0.415209
# 1       0.764434
# 2       0.908867
# 3       0.389007
# 4       0.131121
#           ...
# 5878    0.333243
# 5879    0.000000
# 5880    0.000000
# 5881    0.000000
# 5882    0.000000
# Name: rsIDs, Length: 5883, dtype: float64
# Cluster centers: [[ 0.00000000e+00  3.79131645e-02 -4.64066057e-01 -6.31461234e-02
#   -2.75662632e-02  1.60752429e-01  3.38877524e-01 -6.92159809e-01
#   -8.07572166e-02  1.33559564e-02 -4.22306765e-01 -1.39264080e-02
#    5.52533562e-01 -3.51398944e-01 -3.71170354e-01 -3.04484221e-02
#    5.45346087e-01 -5.12606043e-03 -1.36293045e-04  1.05284799e-01
#    1.11022302e-16 -1.04873511e-01 -5.46212793e-01 -6.23734768e-01
# ...
